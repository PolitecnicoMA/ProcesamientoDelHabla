# %% [markdown]
# # Clasificación de películas usando NLP
#
# Objetivo:
# Predecir el género de una película a partir de sus palabras clave.
#
# Modelos a utilizar:
# - TF-IDF + Naive Bayes
# - LSTM (modelo secuencial)
#
# Métricas:
# - Accuracy
# - Precision
# - Recall
# - F1-score

# %%
#librerias
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("movie_metadata.csv")
df.head()
# Out:
#    Id                                        movie_title  \
# 0   1                                            Avatar
# 1   2          Pirates of the Caribbean: At World's End
# 2   3                                           Spectre
# 3   4                             The Dark Knight Rises
# 4   5  Star Wars: Episode VII - The Force Awakens    ...
#
#                             genero  \
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary
#
#                                        plot_keywords  color  \
# 0             avatar|future|marine|native|paraplegic  Color
# 1  goddess|marriage ceremony|marriage proposal|pi...  Color
# 2                bomb|espionage|sequel|spy|terrorist  Color
# 3  deception|imprisonment|lawlessness|police offi...  Color
# 4                                                NaN    NaN
#
# ...
